# %%
import sys
# !{sys.executable} -m pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\kyle\appdata\local\programs\python\python37-32\lib\site-packages (0.21.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\kyle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-learn) (1.3.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\kyle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-learn) (0.13.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\kyle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-learn) (1.16.2)
# You are using pip version 19.0.3, however version 19.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

from sklearn.svm import SVC
from sklearn import tree        #importing subpackage from sklearn library

# %%
# Loading data from sklearn package
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.8, random_state=0)

# %%
# Tuning Decision Tree


criteria = ["gini", "entropy"]      #criteria to be tested
min_sample_split_range = [2,10, 20] #min sample split to be tested
max_depth_range = [None, 2, 5, 10]  #max depth to be tested
min_samples_leaf_range = [1, 5, 10] #min samples in the leaf to be tested
min_leaf_nodes_range = [None, 5, 10, 20]    #min leaf nodes to be tested

param_grid = {"criterion": criteria,
              "min_samples_split": min_sample_split_range,
              "max_depth": max_depth_range,
              "min_samples_leaf": min_samples_leaf_range,
              "max_leaf_nodes": min_leaf_nodes_range
                }

clf = GridSearchCV(estimator=tree.DecisionTreeClassifier(), 
                    param_grid=param_grid, 
                    cv = 5, 
                    scoring='accuracy', 
                    refit=True)     #setting grid with estimator

clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Grid scores on development set:
# c:\users\kyle\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
# means = clf.cv_results_['mean_test_score']
# stds = clf.cv_results_['std_test_score']
# for mean, std, params in zip(means, stds, clf.cv_results_['params']):
#     print("%0.3f (+/-%0.03f) for %r"
#           % (mean, std * 2, params))
# Out:
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.933 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.700 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.600 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.567 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}

# %%
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
# Out:
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       0.81      0.97      0.88        39
#            2       0.97      0.78      0.86        41
#
#     accuracy                           0.92       120
#    macro avg       0.93      0.92      0.92       120
# weighted avg       0.93      0.92      0.92       120
